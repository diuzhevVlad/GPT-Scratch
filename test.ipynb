# %%
from diuzhev_scratch_llm import BPE
# Out:
# Running cells with 'gpt-scratch (Python 3.12.11)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n gpt-scratch ipykernel --update-deps --force-reinstall'
